# %% [markdown]
# # Heart Disease prediction using KNN

# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'heart.ui'
#
# Created by: PyQt5 UI code generator 5.15.7
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(1118, 885)
        Form.setStyleSheet("\n"
"background-color: qradialgradient(spread:reflect, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0.298507 rgba(255, 255, 255, 255), stop:1 rgba(255, 140, 37, 255));")
        self.frame = QtWidgets.QFrame(Form)
        self.frame.setGeometry(QtCore.QRect(210, 30, 691, 101))
        self.frame.setStyleSheet("background-color: rgb(0, 0, 0);\n"
"border-width: 2px;\n"
"border-radius: 50px;\n"
"")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(20, 30, 661, 41))
        self.label.setStyleSheet("color: rgb(255, 255, 255);\n"
"font: 20pt \"Papyrus\";")
        self.label.setAlignment(QtCore.Qt.AlignCenter)
        self.label.setObjectName("label")
        self.frame_2 = QtWidgets.QFrame(Form)
        self.frame_2.setGeometry(QtCore.QRect(40, 160, 1021, 541))
        self.frame_2.setStyleSheet("\n"
"background-color: rgb(0,0,0);\n"
"font: 12pt \"Lucida Handwriting\";\n"
"color: rgb(255, 255, 255);\n"
"border-radius : 50px;\n"
"\n"
"\n"
"")
        self.frame_2.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_2.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_2.setObjectName("frame_2")
        self.label_2 = QtWidgets.QLabel(self.frame_2)
        self.label_2.setGeometry(QtCore.QRect(60, 50, 81, 31))
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(self.frame_2)
        self.label_3.setGeometry(QtCore.QRect(60, 110, 141, 31))
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(self.frame_2)
        self.label_4.setGeometry(QtCore.QRect(60, 180, 161, 31))
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(self.frame_2)
        self.label_5.setGeometry(QtCore.QRect(60, 240, 191, 31))
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(self.frame_2)
        self.label_6.setGeometry(QtCore.QRect(60, 300, 151, 41))
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(self.frame_2)
        self.label_7.setGeometry(QtCore.QRect(60, 360, 141, 31))
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(self.frame_2)
        self.label_8.setGeometry(QtCore.QRect(550, 50, 211, 31))
        self.label_8.setObjectName("label_8")
        self.label_9 = QtWidgets.QLabel(self.frame_2)
        self.label_9.setGeometry(QtCore.QRect(550, 110, 201, 21))
        self.label_9.setObjectName("label_9")
        self.label_10 = QtWidgets.QLabel(self.frame_2)
        self.label_10.setGeometry(QtCore.QRect(550, 170, 131, 31))
        self.label_10.setObjectName("label_10")
        self.label_11 = QtWidgets.QLabel(self.frame_2)
        self.label_11.setGeometry(QtCore.QRect(550, 230, 161, 41))
        self.label_11.setObjectName("label_11")
        self.label_12 = QtWidgets.QLabel(self.frame_2)
        self.label_12.setGeometry(QtCore.QRect(550, 300, 201, 41))
        self.label_12.setObjectName("label_12")
        self.label_13 = QtWidgets.QLabel(self.frame_2)
        self.label_13.setGeometry(QtCore.QRect(550, 360, 131, 41))
        self.label_13.setObjectName("label_13")
        self.sex_ed = QtWidgets.QLineEdit(self.frame_2)
        self.sex_ed.setGeometry(QtCore.QRect(250, 50, 241, 31))
        self.sex_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"")
        self.sex_ed.setObjectName("sex_ed")
        self.edu_ed = QtWidgets.QLineEdit(self.frame_2)
        self.edu_ed.setGeometry(QtCore.QRect(250, 180, 241, 31))
        self.edu_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"\n"
"")
        self.edu_ed.setObjectName("edu_ed")
        self.age_ed = QtWidgets.QLineEdit(self.frame_2)
        self.age_ed.setGeometry(QtCore.QRect(250, 110, 241, 31))
        self.age_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"")
        self.age_ed.setObjectName("age_ed")
        self.cig_ed = QtWidgets.QLineEdit(self.frame_2)
        self.cig_ed.setGeometry(QtCore.QRect(250, 300, 241, 31))
        self.cig_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"")
        self.cig_ed.setObjectName("cig_ed")
        self.smo_ed = QtWidgets.QLineEdit(self.frame_2)
        self.smo_ed.setGeometry(QtCore.QRect(250, 240, 241, 31))
        self.smo_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"")
        self.smo_ed.setObjectName("smo_ed")
        self.bp_ed = QtWidgets.QLineEdit(self.frame_2)
        self.bp_ed.setGeometry(QtCore.QRect(250, 360, 241, 31))
        self.bp_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"")
        self.bp_ed.setObjectName("bp_ed")
        self.dia_ed = QtWidgets.QLineEdit(self.frame_2)
        self.dia_ed.setGeometry(QtCore.QRect(750, 50, 241, 31))
        self.dia_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"")
        self.dia_ed.setObjectName("dia_ed")
        self.total_ed = QtWidgets.QLineEdit(self.frame_2)
        self.total_ed.setGeometry(QtCore.QRect(750, 110, 241, 31))
        self.total_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"")
        self.total_ed.setObjectName("total_ed")
        self.sys_ed = QtWidgets.QLineEdit(self.frame_2)
        self.sys_ed.setGeometry(QtCore.QRect(750, 180, 241, 31))
        self.sys_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"")
        self.sys_ed.setObjectName("sys_ed")
        self.diabp_ed = QtWidgets.QLineEdit(self.frame_2)
        self.diabp_ed.setGeometry(QtCore.QRect(750, 240, 241, 31))
        self.diabp_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"")
        self.diabp_ed.setObjectName("diabp_ed")
        self.bmi_ed = QtWidgets.QLineEdit(self.frame_2)
        self.bmi_ed.setGeometry(QtCore.QRect(750, 310, 241, 31))
        self.bmi_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"")
        self.bmi_ed.setObjectName("bmi_ed")
        self.heart_ed = QtWidgets.QLineEdit(self.frame_2)
        self.heart_ed.setGeometry(QtCore.QRect(750, 370, 241, 31))
        self.heart_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"")
        self.heart_ed.setObjectName("heart_ed")
        self.label_16 = QtWidgets.QLabel(self.frame_2)
        self.label_16.setGeometry(QtCore.QRect(60, 420, 181, 31))
        self.label_16.setObjectName("label_16")
        self.label_17 = QtWidgets.QLabel(self.frame_2)
        self.label_17.setGeometry(QtCore.QRect(60, 480, 181, 31))
        self.label_17.setObjectName("label_17")
        self.stro_ed = QtWidgets.QLineEdit(self.frame_2)
        self.stro_ed.setGeometry(QtCore.QRect(250, 420, 241, 31))
        self.stro_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"")
        self.stro_ed.setObjectName("stro_ed")
        self.hyp_ed = QtWidgets.QLineEdit(self.frame_2)
        self.hyp_ed.setGeometry(QtCore.QRect(250, 480, 241, 31))
        self.hyp_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"")
        self.hyp_ed.setObjectName("hyp_ed")
        self.label_18 = QtWidgets.QLabel(self.frame_2)
        self.label_18.setGeometry(QtCore.QRect(550, 420, 131, 41))
        self.label_18.setObjectName("label_18")
        self.glu_ed = QtWidgets.QLineEdit(self.frame_2)
        self.glu_ed.setGeometry(QtCore.QRect(750, 430, 241, 31))
        self.glu_ed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(255, 255, 255);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(255, 255, 255) ;\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(255, 126, 34);\n"
"}\n"
"")
        self.glu_ed.setObjectName("glu_ed")
        self.frame_3 = QtWidgets.QFrame(Form)
        self.frame_3.setGeometry(QtCore.QRect(40, 720, 1021, 141))
        self.frame_3.setStyleSheet("background-color: rgb(0,0,0);\n"
"color: rgb(255, 255, 255);\n"
"border-radius: 30px;\n"
"font: 15pt  \"Lucida Handwriting\";")
        self.frame_3.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_3.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_3.setObjectName("frame_3")
        self.label_14 = QtWidgets.QLabel(self.frame_3)
        self.label_14.setGeometry(QtCore.QRect(60, 20, 411, 71))
        self.label_14.setObjectName("label_14")
        self.result = QtWidgets.QLabel(self.frame_3)
        self.result.setGeometry(QtCore.QRect(560, 80, 221, 41))
        font = QtGui.QFont()
        font.setFamily("Lucida Handwriting")
        font.setPointSize(15)
        font.setBold(False)
        font.setItalic(False)
        font.setWeight(50)
        self.result.setFont(font)
        self.result.setText("")
        self.result.setObjectName("result")
        self.pushButton = QtWidgets.QPushButton(self.frame_3)
        self.pushButton.setGeometry(QtCore.QRect(580, 20, 231, 41))
        self.pushButton.setStyleSheet("QPushButton{\n"
"background-color: rgb(255, 255, 255);\n"
"font: 16pt \"MV Boli\";\n"
"color: rgb(3, 3, 3);\n"
"border-radius:10px;\n"
"}\n"
"QPushButton:hover{\n"
"background-color: rgb(255, 126, 34);\n"
"}\n"
"")
        self.pushButton.setObjectName("pushButton")
        self.pushButton.clicked.connect(self.predict)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
        
    def predict(self):
        sex_ed = self.sex_ed.text()
        x1 = sex_ed
        
        age_ed = self.age_ed.text()
        x2 = int(age_ed)
        
        edu_ed = self.edu_ed.text()
        x3 = int(edu_ed)
        
        smo_ed = self.smo_ed.text()
        x4 = smo_ed
        
        cig_ed = self.cig_ed.text()
        x5 = int(cig_ed)
        
        bp_ed = self.bp_ed.text()
        x6 = int(bp_ed)
        
        stro_ed = self.bp_ed.text()
        x7 = int(bp_ed)
        
        hyp_ed = self.hyp_ed.text()
        x8 = int(hyp_ed)
        
        dia_ed = self.dia_ed.text()
        x9 = int(dia_ed)
        
        total_ed = self.total_ed.text()
        x10 = int(total_ed)
        
        sys_ed = self.sys_ed.text()
        x11 = int(sys_ed)
        
        diabp_ed = self.diabp_ed.text()
        x12 = int(diabp_ed)
        
        bmi_ed = self.bmi_ed.text()
        x13 = float(bmi_ed)
        
        heart_ed = self.heart_ed.text()
        x14 = int(heart_ed)
        
        glu_ed = self.glu_ed.text()
        x15 = int(glu_ed)
        
        import pandas as pd
        path = "D:/2022projects/Logistic/To predict heart disease/framingham.csv"
        data = pd.read_csv(path)
        
        data['male'] = data['male'].fillna(value=0)
        data['age'] = data['age'].fillna(value=0)
        data['education'] = data['education'].fillna(value=0)
        data['currentSmoker'] = data['currentSmoker'].fillna(value=0)
        data['cigsPerDay'] = data['cigsPerDay'].fillna(value=0)
        data['BPMeds'] = data['BPMeds'].fillna(value=0)
        data['prevalentStroke'] = data['prevalentStroke'].fillna(value=0)
        data['prevalentHyp'] = data['prevalentHyp'].fillna(value=0)
        data['diabetes'] = data['diabetes'].fillna(value=0)
        data['totChol'] = data['totChol'].fillna(value=0)
        data['sysBP'] = data['sysBP'].fillna(value=0)
        data['diaBP'] = data['diaBP'].fillna(value=0)
        data['BMI'] = data['BMI'].fillna(value=0)
        data['heartRate'] = data['heartRate'].fillna(value=0)
        data['glucose'] = data['glucose'].fillna(value=0)

        x = data.drop('TenYearCHD','columns')
        y = data.TenYearCHD
        
        import sklearn
        from sklearn.model_selection import train_test_split
        x_train , x_test , y_train , y_test = train_test_split(x,y ,test_size=0.2)

        from sklearn.neighbors import KNeighborsClassifier
        #sqrt(n) n=4238 
        model = KNeighborsClassifier(n_neighbors = 65)
        model.fit(x_train, y_train)

        y_pred = model.predict(x_test)
        
        res = model.predict([[x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15]])
        
        if res==0:
            resx='NO'
        else:
            resx='YES'
        print(resx)
        res = str(resx)
        self.result.setText(resx)
        
        from sklearn.metrics import confusion_matrix
        from sklearn.metrics import accuracy_score
        cm=confusion_matrix(y_test,y_pred)
        print("Confusion matrix:",cm)
        print("Accuracy:",accuracy_score(y_test,y_pred)*100)

        
        #print(x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15)
        
    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Heart Disease Prediction"))
        self.label.setText(_translate("Form", "HEART DISEASE PREDICTION"))
        self.label_2.setText(_translate("Form", "Sex:"))
        self.label_3.setText(_translate("Form", "Age:"))
        self.label_4.setText(_translate("Form", "Education:"))
        self.label_5.setText(_translate("Form", "Current Smoker:"))
        self.label_6.setText(_translate("Form", "Cigs Per Day:"))
        self.label_7.setText(_translate("Form", "BP Meds:"))
        self.label_8.setText(_translate("Form", "Diabetes:"))
        self.label_9.setText(_translate("Form", "Total Cholesterol:"))
        self.label_10.setText(_translate("Form", "Systolic BP:"))
        self.label_11.setText(_translate("Form", "Diastolic BP:"))
        self.label_12.setText(_translate("Form", "Body Mass Index:"))
        self.label_13.setText(_translate("Form", "Heart Rate:"))
        self.label_16.setText(_translate("Form", "Prevalet Stroke:"))
        self.label_17.setText(_translate("Form", "Prevalent Hyp:"))
        self.label_18.setText(_translate("Form", "Glucose:"))
        self.label_14.setText(_translate("Form", "Click here to predict whether person \n"
" get heart disease or not:"))
        self.pushButton.setText(_translate("Form", "PREDICT"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# C:\Users\91998\AppData\Local\Temp\ipykernel_1660\1029611022.py:396: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = data.drop('TenYearCHD','columns')
# NO
# C:\Users\91998\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\91998\anaconda3\lib\site-packages\sklearn\base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in Ui_Form.predict(self)
# ...
